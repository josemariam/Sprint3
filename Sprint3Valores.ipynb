# %%
# !pip install requests_html 
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession
url = "https://es.finance.yahoo.com/quote/TEF/history?p=TEF&.tsrc=fin-srch"
s = HTMLSession()
response = s.get(url)
soup = BeautifulSoup(response.content, "html.parser")
t_row = soup.find_all("tr", class_="BdT")
print(t_row)
# Out:
# Requirement already satisfied: requests_html in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: bs4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyquery in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: requests in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (2.27.1)
# Requirement already satisfied: parse in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: fake-useragent in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: w3lib in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: certifi>=2021 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.9)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.7.0)
# Requirement already satisfied: beautifulsoup4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests_html) (2.3.1)
# Requirement already satisfied: lxml>=2.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyquery->requests_html) (4.8.0)
# Requirement already satisfied: cssselect>0.7.9 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: six>=1.4.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from w3lib->requests_html) (1.16.0)
# [<tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>23 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,5100</span></td><td class="Py(10px) Pstart(10px)"><span>3,5200</span></td><td class="Py(10px) Pstart(10px)"><span>3,4700</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>1.491.500</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>22 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6100</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>1.434.900</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>21 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,6300</span></td><td class="Py(10px) Pstart(10px)"><span>3,5400</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>2.057.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>20 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>1.639.600</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>19 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>1.257.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>16 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>1.364.700</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>15 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8800</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>1.726.300</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>14 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8700</span></td><td class="Py(10px) Pstart(10px)"><span>3,9000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>1.511.800</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start ...

# %%
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession

url = "https://es.finance.yahoo.com/quote/TEF/history?p=TEF&.tsrc=fin-srch"

s = HTMLSession()
response = s.get(url)

soup = BeautifulSoup(response.content, "html.parser")
t_row = soup.find_all("tr", class_="BdT")
print(t_row)
# Out:
# [<tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>23 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,5100</span></td><td class="Py(10px) Pstart(10px)"><span>3,5200</span></td><td class="Py(10px) Pstart(10px)"><span>3,4700</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>1.491.500</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>22 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6100</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>1.434.900</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>21 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,6300</span></td><td class="Py(10px) Pstart(10px)"><span>3,5400</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>2.057.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>20 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>1.639.600</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>19 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>1.257.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>16 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>1.364.700</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>15 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8800</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>3,8100</span></td><td class="Py(10px) Pstart(10px)"><span>1.726.300</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>14 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8700</span></td><td class="Py(10px) Pstart(10px)"><span>3,9000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>3,8600</span></td><td class="Py(10px) Pstart(10px)"><span>1.511.800</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start ...

# %%
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession

url = "https://es.finance.yahoo.com/quote/TEF/history?p=TEF&.tsrc=fin-srch"

s = HTMLSession()
response = s.get(url)

soup = BeautifulSoup(response.content, "html.parser")
print(t_row)
t_row = soup.find all("tr")
class="BdT")
fechas = (1
aperturas = []
maximos = [1
minimos
cierres =11
cierres ajus = []
volumen = [1

           for t_r in t_row:
fechas. append (t_row. find _all("tr") [0].get text())
aperturas. append (t_row.find all("tr")[1).get textO))
maximos.append(t_row.find_all("tr")[2].get_text())
minimos.append(t_row.find_all("tr")[3].get_text())
cierres.append(trow.findall("tr")[4].get_text())
cierres_ajus.append(t_row.find_all("tr")[5].get_text())
volumen.append(t_row.findall("tr")[6].get_text())
print(t row)
# Out:
#   Input In [12]
#     t_row = soup.find all("tr")
#                       ^
# SyntaxError: invalid syntax

# %%
# !pip install requests_html
import requests
from bs4 import BeautifulSoup
from requests_html import HTMLSession

url = "https://es.finance.yahoo.com/quote/TEF/history?p=TEF&.tsrc=fin-srch"

s = HTMLSession()
response = s.get(url)

soup = BeautifulSoup(response.content, "html.parser")
t_row = soup.find_all("tr", class_="BdT")
print(t_row)
# Out:
# Requirement already satisfied: requests_html in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: bs4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: parse in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.19.0)
# Requirement already satisfied: w3lib in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: fake-useragent in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (0.1.11)
# Requirement already satisfied: requests in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (2.27.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: pyquery in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests_html) (1.4.3)
# Requirement already satisfied: certifi>=2021 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.9)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.7.0)
# Requirement already satisfied: beautifulsoup4 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests_html) (2.3.1)
# Requirement already satisfied: cssselect>0.7.9 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from pyquery->requests_html) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests->requests_html) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: six>=1.4.1 in /Users/josemariamunoz/opt/anaconda3/lib/python3.9/site-packages (from w3lib->requests_html) (1.16.0)
# [<tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>27 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,3600</span></td><td class="Py(10px) Pstart(10px)"><span>3,3899</span></td><td class="Py(10px) Pstart(10px)"><span>3,3250</span></td><td class="Py(10px) Pstart(10px)"><span>3,3300</span></td><td class="Py(10px) Pstart(10px)"><span>3,3300</span></td><td class="Py(10px) Pstart(10px)"><span>2.180.828</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>26 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,3900</span></td><td class="Py(10px) Pstart(10px)"><span>3,4200</span></td><td class="Py(10px) Pstart(10px)"><span>3,3400</span></td><td class="Py(10px) Pstart(10px)"><span>3,3500</span></td><td class="Py(10px) Pstart(10px)"><span>3,3500</span></td><td class="Py(10px) Pstart(10px)"><span>2.420.700</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>23 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,5100</span></td><td class="Py(10px) Pstart(10px)"><span>3,5200</span></td><td class="Py(10px) Pstart(10px)"><span>3,4700</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>3,4900</span></td><td class="Py(10px) Pstart(10px)"><span>1.491.500</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>22 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6100</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>1.434.900</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>21 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,6200</span></td><td class="Py(10px) Pstart(10px)"><span>3,6300</span></td><td class="Py(10px) Pstart(10px)"><span>3,5400</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>3,5700</span></td><td class="Py(10px) Pstart(10px)"><span>2.057.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>20 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>3,7300</span></td><td class="Py(10px) Pstart(10px)"><span>1.639.600</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>19 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>3,8400</span></td><td class="Py(10px) Pstart(10px)"><span>1.257.200</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start) Pend(10px)"><span>16 sept 2022</span></td><td class="Py(10px) Pstart(10px)"><span>3,8000</span></td><td class="Py(10px) Pstart(10px)"><span>3,8500</span></td><td class="Py(10px) Pstart(10px)"><span>3,7800</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>3,8300</span></td><td class="Py(10px) Pstart(10px)"><span>1.364.700</span></td></tr>, <tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)"><td class="Py(10px) Ta(start ...
